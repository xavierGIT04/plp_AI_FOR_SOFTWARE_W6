# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
import numpy as np
import time

# --- 1. Define and Load a Lightweight Model ---
# We use MobileNetV2, a model designed for mobile and edge devices.
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False, # Exclude the final classification layer
    input_shape=(160, 160, 3)
)
base_model.trainable = False # Freeze the base layers

# Add custom classification layers for 'Recyclable Items' (e.g., 3 classes: metal, paper, plastic)
x = base_model.output
x = GlobalAveragePooling2D()(x)
# Replace 'NUM_CLASSES' with the actual number of classes in your recycling dataset
NUM_CLASSES = 3
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# --- 2. Training Simulation (Conceptual) ---
# In a real scenario, you would compile and train the model here:
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# model.fit(train_data, epochs=10)
print("Model created (simulating training on recycling dataset)...")

# --- 3. Convert to TensorFlow Lite (.tflite) ---
print("Starting TFLite conversion...")
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Optimize for size and speed (critical for Edge deployment)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Convert the model
tflite_model = converter.convert()

# Save the TFLite model to a file
tflite_model_path = 'recyclable_classifier.tflite'
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_model)

print(f"Conversion complete. TFLite model saved to: {tflite_model_path}")

# --- 4. Edge Inference Simulation and Latency Metric ---
# Simulate running the model on a device like Raspberry Pi
interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Create a sample input image (simulated 160x160 RGB)
sample_input = np.random.rand(1, 160, 160, 3).astype(np.float32)

# Measure inference latency
start_time = time.time()
interpreter.set_tensor(input_details[0]['index'], sample_input)
interpreter.invoke()
output_data = interpreter.get_tensor(output_details[0]['index'])
end_time = time.time()

latency_ms = (end_time - start_time) * 1000
simulated_accuracy = 0.88 # Placeholder for actual metric

# --- 5. Output Metrics and Explanation ---
print("\n--- Edge Deployment Metrics (Simulated) ---")
print(f"Simulated Model Accuracy: {simulated_accuracy:.2f}")
print(f"Inference Latency on Edge Device: {latency_ms:.2f} ms")
print(f"Model Size: {len(tflite_model) / 1024**2:.2f} MB")
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.30.2 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_160_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 6s 1us/step
# Model created (simulating training on recycling dataset)...
# Starting TFLite conversion...
# INFO:tensorflow:Assets written to: C:\Users\USER\AppData\Local\Temp\tmpdcm_p4x8\assets
# INFO:tensorflow:Assets written to: C:\Users\USER\AppData\Local\Temp\tmpdcm_p4x8\assets
# Saved artifact at 'C:\Users\USER\AppData\Local\Temp\tmpdcm_p4x8'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   2980019147728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019149648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019151568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019151184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019150032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019151760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019150224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019152336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019151952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019149840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019149264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019153488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019153680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019150416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019150992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019154256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019156368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019156560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019155408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019154832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019153296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019157712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019157904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019157136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019154640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019156752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019155216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019158288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019157328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019158864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019156176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019158480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019157520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019158672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019158096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980019155600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036707920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036708112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036707344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036706768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036708496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036708688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036707728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036708304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036709264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036709648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036709840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036708880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036709456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036710416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036707536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036710032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036710224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036706960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036711376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036710800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036710992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036711184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036706576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036712336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036711760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036711952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036712144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036709072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036713296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036712720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036712912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036713104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036710608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036714256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036713680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036713872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036714064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036711568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036715216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036714640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036714832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036715024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036712528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036716176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036715600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036715792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036715984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036713488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036717136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036716560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036716752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036716944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036714448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036718096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036717520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036717712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036717904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036715408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036719056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036718480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036718672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036718864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036716368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036720016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036719440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036719632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036719824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036717328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036720976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036720400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036720592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036720784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036718288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036721936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036721360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036721552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036722128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036722512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036721168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036720208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036721744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037558736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036722320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980036719248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037558544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037559312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037559120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037558928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037560464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037559888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037560080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037560272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037559504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037561424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037560848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037561040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037561232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037558352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037562384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037561808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037562000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037562192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037559696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037563344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037562768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037562960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037563152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037560656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037564304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037563728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037563920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037564112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037561616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037565264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037564688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037564880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037565072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037562576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037566224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037565648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037565840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037566032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037563536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037567184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037566608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037566800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037566992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037564496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037568144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037567568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037567760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037567952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037565456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037569104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037568528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037568720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037568912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037566416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037570064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037569488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037569680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037569872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037567376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037571024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037570448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037570640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037570832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037568336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037571984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037571408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037571600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037571792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037569296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037572944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037572368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037572560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037572752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037570256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037573904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037573328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037573520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037574096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037574480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037573136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037572176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037573712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038460624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037574288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980037571216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038460240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038459664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038459472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038459856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038461584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038461008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038461200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038461392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038460432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038462544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038461968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038462160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038462352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038460048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038463504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038462928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038463120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038463312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038460816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038464464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038463888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038464080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038464272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038461776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038465424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038464848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038465040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038465232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038462736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038466384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038465808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038466000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038466192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038463696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038467344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038466768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038466960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038467152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038464656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038468304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038467728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038467920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038468112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038465616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038469264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038468688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038468880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038469072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038466576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038470224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038469648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038469840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038470032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038467536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038471184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038468496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2980038471952: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Conversion complete. TFLite model saved to: recyclable_classifier.tflite
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# --- Edge Deployment Metrics (Simulated) ---
# Simulated Model Accuracy: 0.88
# Inference Latency on Edge Device: 112.72 ms
# Model Size: 2.39 MB
